# %% [markdown]
# # Sudoku

# %%
import sys

sys.path.append('../../')
import time

import torch
from dataGen import dataList, obsList, test_loader, train_loader
from network import Sudoku_Net

from neurasp import NeurASP

# %% [markdown]
# ## NeurASP program

# %%
dprogram = r'''
% neural rule
nn(sol(81, config), [1,2,3,4,5,6,7,8,9]).

% we assign one number at each position (R,C)
a(R,C,N) :- sol(config, Pos, N), R=Pos/9, C=Pos\9.

% it's a mistake if the same number shows 2 times in a row
:- a(R,C1,N), a(R,C2,N), C1!=C2.

% it's a mistake if the same number shows 2 times in a column
:- a(R1,C,N), a(R2,C,N), R1!=R2.

% it's a mistake if the same number shows 2 times in a 3*3 grid
:- a(R,C,N), a(R1,C1,N), R!=R1, C!=C1, ((R/3)*3 + C/3) = ((R1/3)*3 + C1/3).
'''

# %% [markdown]
# ## Neural Network Instantiation
# - Instantiate neural networks.
# - Define nnMapping: a dictionary that maps neural network names (i.e., strings) to the neural network objects (i.e., torch.nn.Module object)
# - Define optimizers: a dictionary that specifies the optimizer for each network (we use the Adam optimizer here).

# %%
m = Sudoku_Net()
nnMapping = {'sol': m}
optimizers = {'sol': torch.optim.Adam(m.parameters(), lr=0.0001)}

# %% [markdown]
# ## Create NeurASP Object
#
# We use all constraints to train the neural network, which corresponds to the experiment nr-p-r-opt at the table at the end of this document.

# %%
NeurASPobj = NeurASP(dprogram, nnMapping, optimizers, gpu=False)

dataset = list(zip(dataList, obsList))
# Out:
# Device: cpu

# %% [markdown]
# ## Training and Testing

# %%
startTime = time.time()
print('Initial test accuracy (whole board): {:0.2f}%\nInitial test accuracy (single cell): {:0.2f}%'.format(*NeurASPobj.testNN('sol', test_loader)))

for i in range(100):
    print(f'Training for Epoch {i+1}...')
    time1 = time.time()
    NeurASPobj.learn(dataset, epoch=1, bar=True, task='solvingSudoku')
    time2 = time.time()
    acc, singleAcc = NeurASPobj.testNN('predict', train_loader)
    print(f'Train Acc (whole board): {acc:0.2f}%')
    print(f'Train Acc (single cell): {singleAcc:0.2f}%')
    acc, singleAcc = NeurASPobj.testNN('predict', test_loader)
    print(f'Test Acc (whole board): {acc:0.2f}%')
    print(f'Test Acc (single cell): {singleAcc:0.2f}%')
    print("--- train time: %s seconds ---" % (time2 - time1))
    print("--- test time: %s seconds ---" % (time.time() - time2))
    print('--- total time from beginning: %s minutes ---' % int((time.time() - startTime)/60) )
    
    saveModelPath = f'data/model_data70k_alpha0_batchSize1_epoch{i+1}'
    print(f'Storing the trained model into {saveModelPath}')
    torch.save(m.state_dict(), saveModelPath)
# Out:
# Initial test accuracy (whole board): 0.00%
# Initial test accuracy (single cell): 11.11%
# Training for Epoch 1...
#   0%|          | 0/63000 [16:00<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/PycharmProjects/NeurASP/neurasp.py:322, in NeurASP.learn(self, dataset, epoch, lossFunc, method, lr, opt, storeSM, accStep, bar, seed, valDataset, task)
#     321 try:
# --> 322     models = self.stableModels[obs[b]]
#     323 except KeyError:
#
# KeyError: ':- not sol(2, config, 7).\n:- not sol(4, config, 5).\n:- not sol(8, config, 6).\n:- not sol(9, config, 5).\n:- not sol(10, config, 2).\n:- not sol(12, config, 7).\n:- not sol(13, config, 6).\n:- not sol(18, config, 6).\n:- not sol(20, config, 8).\n:- not sol(28, config, 4).\n:- not sol(33, config, 5).\n:- not sol(34, config, 2).\n:- not sol(35, config, 3).\n:- not sol(36, config, 2).\n:- not sol(37, config, 7).\n:- not sol(39, config, 4).\n:- not sol(44, config, 9).\n:- not sol(47, config, 9).\n:- not sol(48, config, 2).\n:- not sol(49, config, 8).\n:- not sol(51, config, 1).\n:- not sol(62, config, 8).\n:- not sol(63, config, 7).\n:- not sol(64, config, 8).\n:- not sol(67, config, 2).\n:- not sol(68, config, 3).\n:- not sol(70, config, 9).\n:- not sol(72, config, 9).\n:- not sol(73, config, 3).\n:- not sol(74, config, 4).\n:- not sol(75, config, 5).\n:- not sol(76, config, 7).\n:- not sol(78, config, 2).\n:- not sol(79, config, 6).\n'
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[20], line 7
#       5 print('Training for Epoch {}...'.format(i+1))
#       6 time1 = time.time()
# ----> 7 NeurASPobj.learn(dataset, epoch=1, bar=True, task='solvingSudoku')
#       8 time2 = time.time()
#       9 acc, singleAcc = NeurASPobj.testNN('predict', train_loader)
#
# File ~/PycharmProjects/NeurASP/neurasp.py:324, in NeurASP.learn(self, dataset, epoch, lossFunc, method, lr, opt, storeSM, accStep, bar, seed, valDataset, task)
#     322     models = self.stableModels[obs[b]]
#     323 except KeyError:
# --> 324     models = dmvpp.find_k_SM_under_obs(obs[b], k=0, opt=opt)
#     325     self.stableModels[obs[b]] = models
#     326 gradients = dmvpp.mvppLearn(models)
#
# File ~/PycharmProjects/NeurASP/mvpp.py:191, in MVPP.find_k_SM_under_obs(self, obs, k, opt)
#     189     print("\nPi': \n{}".format(program))
#     190 clingo_control.ground([("base", [])])
# --> 191 clingo_control.solve(on_model=model_fun)
#     192 return torch.IntTensor(models)
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/control.py:848, in Control.solve(self, assumptions, on_model, on_unsat, on_statistics, on_finish, on_core, yield_, async_)
#     844 if async_:
#     845     mode |= _lib.clingo_solve_mode_async
#     847 handle = SolveHandle(
# --> 848     _c_call(
#     849         "clingo_solve_handle_t*",
#     850         _lib.clingo_control_solve,
#     851         self._rep,
#     852         mode,
#     853         p_ass,
#     854         len(assumptions),
#     855         _lib.pyclingo_solve_event_callback,
#     856         self._handler,
#     857         handler=data,
#     858     ),
#     859     data,
#     860 )
#     862 if not yield_ and not async_:
#     863     with handle:
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/_internal.py:44, in _c_call(c_type, c_fun, handler, *args)
#      42 else:
#      43     p_ret = c_type
# ---> 44 _handle_error(c_fun(*args, p_ret), handler)
#      45 return p_ret[0]
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/_internal.py:71, in _handle_error(ret, handler)
#      65 code = _lib.clingo_error_code()
#      66 if (
#      67     code == _lib.clingo_error_unknown
#      68     and handler is not None
#      69     and handler.error is not None
#      70 ):
# ---> 71     raise handler.error[0](handler.error[1]).with_traceback(handler.error[2])
#      72 msg = _ffi.string(_lib.clingo_error_message()).decode()
#      73 if code == _lib.clingo_error_bad_alloc:
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/control.py:121, in _pyclingo_solve_event_callback(type_, event, data, goon)
#     118     handler.on_finish(_ffi.cast("clingo_solve_result_bitset_t*", event)[0])
#     120 if type_ == _lib.clingo_solve_event_type_model:
# --> 121     goon[0] = handler.on_model(_ffi.cast("clingo_model_t*", event))
#     123 if type_ == _lib.clingo_solve_event_type_unsat:
#     124     c_args = _ffi.cast("void**", event)
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/control.py:93, in _SolveEventHandler.on_model(self, m)
#      91 ret = None
#      92 if self._on_model is not None:
# ---> 93     ret = self._on_model(Model(m))
#      94 return bool(ret or ret is None)
#
# File ~/PycharmProjects/NeurASP/mvpp.py:183, in MVPP.find_k_SM_under_obs.<locals>.model_fun(model)
#     182 def model_fun(model):
# --> 183     models.append(self.model_to_network_preds(model))
#
# File ~/PycharmProjects/NeurASP/mvpp.py:153, in MVPP.model_to_network_preds(self, m)
#     151 def model_to_network_preds(self, m):
#     152     # Extract network predictions from stable model
# --> 153     m = str(m).split(' ')
#     154     network_preds = [0 for _ in m]
#     155     for atom in m:
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/solving.py:430, in Model.__str__(self)
#     429 def __str__(self):
# --> 430     return " ".join(map(str, self.symbols(shown=True)))
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/symbol.py:95, in Symbol.__str__(self)
#      94 def __str__(self) -> str:
# ---> 95     return _str(
#      96         _lib.clingo_symbol_to_string_size, _lib.clingo_symbol_to_string, self._rep
#      97     )
#
# File ~/PycharmProjects/NeurASP/venv/lib/python3.10/site-packages/clingo/_internal.py:31, in _str(f_size, f_str, handler, *args)
#      29 _handle_error(f_size(*args, p_size), handler)
#      30 p_str = _ffi.new("char[]", p_size[0])
# ---> 31 _handle_error(f_str(*args, p_str, p_size[0]), handler)
#      32 return _ffi.string(p_str).decode()
#
# KeyboardInterrupt:
